# %% [markdown]
# CHECK SAKILA

# %%
import duckdb

# connect to duckdb database
with duckdb.connect("data/sakila.duckdb") as conn:
    actor = conn.sql("from staging.actor;").df()

actor.head()
# Out:
#    actor_id first_name     last_name         last_update        _dlt_load_id  \
# 0       1.0   PENELOPE       GUINESS 2021-03-06 15:51:59  1764951453.6444108
# 1       2.0       NICK      WAHLBERG 2021-03-06 15:51:59  1764951453.6444108
# 2       3.0         ED         CHASE 2021-03-06 15:51:59  1764951453.6444108
# 3       4.0   JENNIFER         DAVIS 2021-03-06 15:51:59  1764951453.6444108
# 4       5.0     JOHNNY  LOLLOBRIGIDA 2021-03-06 15:51:59  1764951453.6444108
#
#           _dlt_id
# 0  6/evFZ12Kbe3ew
# 1  Dw7CVMmV7AONEA
# 2  a0CbXwRhyzlewA
# 3  tAhjWZHvuwJuig
# 4  EzKU9qH/ZdBkkQ
